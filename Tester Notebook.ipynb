# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp '/content/drive/MyDrive/ProjectMLHC/eval/project.zip' .

# %%
# !unzip project.zip
# Out:
# Archive:  project.zip
#   inflating: project/__init__.py
#   inflating: project/eval_functions.py
#    creating: project/meta_data/
#   inflating: project/meta_data/initial_cohort.csv
#   inflating: project/meta_data/labs_metadata.csv
#   inflating: project/meta_data/vital_metadata.csv
#   inflating: project/preprocessing.py
#   inflating: project/requirements.txt
#    creating: project/saved_models/
#   inflating: project/saved_models/model_mort
#   inflating: project/saved_models/model_prolonged
#   inflating: project/saved_models/model_readmission
#   inflating: project/saved_models/preprocess_mort
#   inflating: project/saved_models/preprocess_prolonged
#   inflating: project/saved_models/preprocess_readmission
#   inflating: project/saved_models/preprocess_tabular
#   inflating: project/unseen_data_evaluation.py

# %%
# !pip install -r project/requirements.txt
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r project/requirements.txt (line 1)) (1.5.3)
# Requirement already satisfied: google in /usr/local/lib/python3.10/dist-packages (from -r project/requirements.txt (line 2)) (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r project/requirements.txt (line 3)) (1.23.5)
# Collecting transformers~=4.33.2 (from -r project/requirements.txt (line 4))
#   Downloading transformers-4.33.2-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 51.3 MB/s eta 0:00:00
# Collecting datasets (from -r project/requirements.txt (line 5))
#   Downloading datasets-2.14.5-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 47.3 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from -r project/requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: scikit-learn~=1.2.2 in /usr/local/lib/python3.10/dist-packages (from -r project/requirements.txt (line 7)) (1.2.2)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from -r project/requirements.txt (line 8)) (1.7.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r project/requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r project/requirements.txt (line 1)) (2023.3.post1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from google->-r project/requirements.txt (line 2)) (4.11.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers~=4.33.2->-r project/requirements.txt (line 4)) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers~=4.33.2->-r project/requirements.txt (line 4))
#   Downloading huggingface_hub-0.17.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 28.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers~=4.33.2->-r project/requirements.txt (line 4)) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers~=4.33.2->-r project/requirements.txt (line 4)) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers~=4.33.2->-r project/requirements.txt (line 4)) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers~=4.33.2->-r project/requirements.txt (line 4)) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers~=4.33.2->-r project/requirements.txt (line 4))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 90.6 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers~=4.33.2->-r project/requirements.txt (line 4))
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 50.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers~=4.33.2->-r project/requirements.txt (line 4)) (4.66.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r project/requirements.txt (line 5)) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets->-r project/requirements.txt (line 5))
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.8 MB/s eta 0:00:00
# Collecting xxhash (from datasets->-r project/requirements.txt (line 5))
#   Downloading xxhash-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.7 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->-r project/requirements.txt (line 5))
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r project/requirements.txt (line 5)) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->-r project/requirements.txt (line 5)) (3.8.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn~=1.2.2->-r project/requirements.txt (line 7)) (1.11.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn~=1.2.2->-r project/requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r project/requirements.txt (line 5)) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r project/requirements.txt (line 5)) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r project/requirements.txt (line 5)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r project/requirements.txt (line 5)) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r project/requirements.txt (line 5)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r project/requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r project/requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers~=4.33.2->-r project/requirements.txt (line 4)) (4.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->-r project/requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers~=4.33.2->-r project/requirements.txt (line 4)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers~=4.33.2->-r project/requirements.txt (line 4)) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers~=4.33.2->-r project/requirements.txt (line 4)) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->google->-r project/requirements.txt (line 2)) (2.5)
# Installing collected packages: tokenizers, safetensors, xxhash, dill, multiprocess, huggingface-hub, transformers, datasets
# Successfully installed datasets-2.14.5 dill-0.3.7 huggingface-hub-0.17.2 multiprocess-0.70.15 safetensors-0.3.3 tokenizers-0.13.3 transformers-4.33.2 xxhash-3.3.0

# %%
from project import run_pipeline_on_unseen_data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import auth
from google.cloud import bigquery
from google.colab import data_table

# %%
project = 'taumlhc'
client = bigquery.Client(project)
data_table.enable_dataframe_formatter()
auth.authenticate_user()

# %%
test = pd.read_csv('/content/drive/MyDrive/ProjectMLHC/eval/test_example.csv')
predction_df = run_pipeline_on_unseen_data(test['subject_id'].to_list(), client)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-7-690fb4db89c6> in <cell line: 2>()
#       1 test = pd.read_csv('/content/drive/MyDrive/ProjectMLHC/eval/test_example.csv')
# ----> 2 predction_df = run_pipeline_on_unseen_data(test['subject_id'].to_list(), client)
#
# /content/project/unseen_data_evaluation.py in run_pipeline_on_unseen_data(subject_ids, client)
#      31     subject_ids = pd.Series(subject_ids, name='subject_id')
#      32     # GENERAL PREPROCESS
# ---> 33     preprocess(subject_ids=subject_ids, client=client)
#      34     df = pd.read_csv('final_df.csv')
#      35
#
# /content/project/preprocessing.py in preprocess(subject_ids, client)
#      42
#      43     gc.collect()
# ---> 44     notes = load_notes()
#      45     gc.collect()
#      46
#
# /content/project/preprocessing.py in load_notes()
#      34             """
#      35
# ---> 36         notes1 = client.query(notes_query).result().to_dataframe().rename(str.lower, axis='columns')
#      37
#      38         # initial_cohort = pd.read_csv(file_path + '/meta_data/initial_cohort.csv')
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/client.py in query(self, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry, api_method)
#    3401             )
#    3402         elif api_method == enums.QueryApiMethod.INSERT:
# -> 3403             return _job_helpers.query_jobs_insert(
#    3404                 self,
#    3405                 query,
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/_job_helpers.py in query_jobs_insert(client, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry)
#     112             return query_job
#     113
# --> 114     future = do_query()
#     115     # The future might be in a failed state now, but if it's
#     116     # unrecoverable, we'll find out when we ask for it's result, at which
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/_job_helpers.py in do_query()
#      89
#      90         try:
# ---> 91             query_job._begin(retry=retry, timeout=timeout)
#      92         except core_exceptions.Conflict as create_exc:
#      93             # The thought is if someone is providing their own job IDs and they get
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/job/query.py in _begin(self, client, retry, timeout)
#    1308
#    1309         try:
# -> 1310             super(QueryJob, self)._begin(client=client, retry=retry, timeout=timeout)
#    1311         except exceptions.GoogleAPICallError as exc:
#    1312             exc.message = _EXCEPTION_FOOTER_TEMPLATE.format(
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/job/base.py in _begin(self, client, retry, timeout)
#     691         # job has an ID.
#     692         span_attributes = {"path": path}
# --> 693         api_response = client._call_api(
#     694             retry,
#     695             span_name="BigQuery.job.begin",
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/client.py in _call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     811                 name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     812             ):
# --> 813                 return call()
#     814
#     815         return call()
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/_http/__init__.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     492
#     493         if not 200 <= response.status_code < 300:
# --> 494             raise exceptions.from_http_response(response)
#     495
#     496         if expect_json and response.content:
#
# Forbidden: 403 POST https://bigquery.googleapis.com/bigquery/v2/projects/taumlhc/jobs?prettyPrint=false: Access Denied: Project taumlhc: User does not have bigquery.jobs.create permission in project taumlhc.
#
# Location: None
# Job ID: 68bb23d0-2378-4f31-911e-eac7b37ee8e2

# %%
# @title Validate Shape
assert(isinstance(predction_df, pd.DataFrame))
assert(predction_df.shape[1] == 4)
assert(set(predction_df.columns) == set(['subject_id', 'mortality_proba', 'prolonged_LOS_proba', 'readmission_proba']))

# %%
# @title Show Data Sample
predction_df.head()

# %%
# @title Probability Plots
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.hist(predction_df['mortality_proba'], range=(0, 1), bins=10)
ax.set_xlabel('Mortality Probabilities')
ax.set_ylabel('Count')

fig, ax = plt.subplots()
ax.hist(predction_df['prolonged_LOS_proba'], range=(0, 1), bins=10)
ax.set_xlabel('Prolonged Length of Stay Probabilities')
ax.set_ylabel('Count')

fig, ax = plt.subplots()
ax.hist(predction_df['readmission_proba'], range=(0, 1), bins=10)
ax.set_xlabel('Readmission Probabilities')
ax.set_ylabel('Count')

plt.show()
